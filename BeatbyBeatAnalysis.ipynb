# %%
import pandas as pd
import numpy as np

def std(x): 
    return np.std(x)

# %%
data=pd.read_csv('/content/test_predictions (6).csv',header=None)
data.rename(columns={0:'FileName',1:'Frame',2:'EF'},inplace=True)

#data1=pd.read_csv('/content/test_predictions (7).csv',header=None)
#data.rename(columns={0:'FileName',1:'Frame',2:'EF'},inplace=True)

#data2=pd.read_csv('/content/test_predictions (8).csv',header=None)
#data.rename(columns={0:'FileName',1:'Frame',2:'EF'},inplace=True)


data
# Out:
#                       FileName  Frame       EF
# 0       0X100CF05D141FF143.avi      0  59.7213
# 1       0X100CF05D141FF143.avi      1  59.8741
# 2       0X100CF05D141FF143.avi      2  59.4931
# 3       0X100CF05D141FF143.avi      3  59.7089
# 4       0X100CF05D141FF143.avi      4  59.5561
# ...                        ...    ...      ...
# 147266   0XFE6E32991136338.avi     53  33.8676
# 147267   0XFE6E32991136338.avi     54  33.5740
# 147268   0XFE6E32991136338.avi     55  34.2721
# 147269   0XFE6E32991136338.avi     56  34.2065
# 147270   0XFE6E32991136338.avi     57  34.4417
#
# [147271 rows x 3 columns]

# %%
dataNoAugmentation=data[data['Frame']==0]
#dataNoAugmentation1=data1[data1['Frame']==0]
#dataNoAugmentation2=data2[data2['Frame']==0]


dataNoAugmentation
# Out:
#                       FileName  Frame       EF
# 0       0X100CF05D141FF143.avi      0  59.7213
# 186     0X1012703CDC1436FE.avi      0  38.3652
# 325     0X102CFB07F752AAE6.avi      0  52.7867
# 480     0X105B9EF57DE45DCB.avi      0  55.8331
# 620     0X10A28877E97DF540.avi      0  60.6997
# ...                        ...    ...      ...
# 146702   0XECF82DC9301EE77.avi      0  66.8003
# 146816   0XF557EF658FD13D0.avi      0  55.5773
# 146933   0XF6661AF354401A5.avi      0  61.6972
# 147092   0XF829F634971A0F7.avi      0  58.8671
# 147213   0XFE6E32991136338.avi      0  32.6225
#
# [1276 rows x 3 columns]

# %%
dataGlobalAugmentation=data.groupby('FileName')['EF'].agg(['mean', std])
dataGlobalAugmentation_1=dataGlobalAugmentation[dataGlobalAugmentation['FileName']=='F0X105B9EF57DE45DCB.avi']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FileName'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sizeData=pd.read_csv('/content/size.csv')
sizeData
# Out:
#                       Filename  Frame  Size  HumanLarge  HumanSmall  \
# 0       0X100CF05D141FF143.avi      0  1360           0           0
# 1       0X100CF05D141FF143.avi      1  1362           0           0
# 2       0X100CF05D141FF143.avi      2  1348           0           0
# 3       0X100CF05D141FF143.avi      3  1334           0           0
# 4       0X100CF05D141FF143.avi      4  1333           0           0
# ...                        ...    ...   ...         ...         ...
# 226267   0XFE6E32991136338.avi    115  1235           0           0
# 226268   0XFE6E32991136338.avi    116  1219           0           0
# 226269   0XFE6E32991136338.avi    117  1205           0           0
# 226270   0XFE6E32991136338.avi    118  1209           0           0
# 226271   0XFE6E32991136338.avi    119  1197           0           0
#
#         ComputerSmall
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...

# %%
sizeData=sizeData[sizeData['ComputerSmall']==1]
sizeData
# Out:
#                       Filename  Frame  Size  HumanLarge  HumanSmall  \
# 19      0X100CF05D141FF143.avi     19   878           0           0
# 87      0X100CF05D141FF143.avi     87   782           0           0
# 146     0X100CF05D141FF143.avi    146   864           0           0
# 208     0X100CF05D141FF143.avi    208   851           0           0
# 271     0X1012703CDC1436FE.avi     23  1732           0           0
# ...                        ...    ...   ...         ...         ...
# 226123   0XF829F634971A0F7.avi    154   737           0           0
# 226167   0XFE6E32991136338.avi     15   929           0           0
# 226197   0XFE6E32991136338.avi     45  1015           1           0
# 226225   0XFE6E32991136338.avi     73  1040           0           0
# 226256   0XFE6E32991136338.avi    104   925           0           0
#
#         ComputerSmall
# 19                  1
# 87                  1
# 146                 1
# 208                 1
# 271                 1
# ...

# %%
sizeData.columns
sizeRelevantFrames=sizeData[['Filename', 'Frame']]

# %%
sizeData
# Out:
#                       Filename  Frame  Size  HumanLarge  HumanSmall  \
# 19      0X100CF05D141FF143.avi     19   878           0           0
# 87      0X100CF05D141FF143.avi     87   782           0           0
# 146     0X100CF05D141FF143.avi    146   864           0           0
# 208     0X100CF05D141FF143.avi    208   851           0           0
# 271     0X1012703CDC1436FE.avi     23  1732           0           0
# ...                        ...    ...   ...         ...         ...
# 226123   0XF829F634971A0F7.avi    154   737           0           0
# 226167   0XFE6E32991136338.avi     15   929           0           0
# 226197   0XFE6E32991136338.avi     45  1015           1           0
# 226225   0XFE6E32991136338.avi     73  1040           0           0
# 226256   0XFE6E32991136338.avi    104   925           0           0
#
#         ComputerSmall
# 19                  1
# 87                  1
# 146                 1
# 208                 1
# 271                 1
# ...

# %%
sizeRelevantFrames
# Out:
#                       Filename  Frame
# 19      0X100CF05D141FF143.avi     19
# 87      0X100CF05D141FF143.avi     87
# 146     0X100CF05D141FF143.avi    146
# 208     0X100CF05D141FF143.avi    208
# 271     0X1012703CDC1436FE.avi     23
# ...                        ...    ...
# 226123   0XF829F634971A0F7.avi    154
# 226167   0XFE6E32991136338.avi     15
# 226197   0XFE6E32991136338.avi     45
# 226225   0XFE6E32991136338.avi     73
# 226256   0XFE6E32991136338.avi    104
#
# [4999 rows x 2 columns]

# %%
sizeRelevantFrames['Frame']=sizeRelevantFrames['Frame']-32
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sizeRelevantFrames['Frame']=sizeRelevantFrames['Frame'].apply(lambda x: 0 if x<0 else x)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sizeRelevantFrames.rename(columns={'Filename':'FileName'},inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
sizeRelevantFramesa = sizeRelevantFrames[sizeRelevantFrames['FileName']=='0X105B9EF57DE45DCB.avi']

# %%
sizeRelevantFramesa
# Out:
#                    FileName  Frame
# 687  0X105B9EF57DE45DCB.avi      0
# 737  0X105B9EF57DE45DCB.avi     39
# 793  0X105B9EF57DE45DCB.avi     95
# 836  0X105B9EF57DE45DCB.avi    138

# %%
beatByBeat=pd.merge(sizeRelevantFrames, data, how='inner',on=['FileName','Frame'])

# %%
beatByBeat
# Out:
#                     FileName  Frame       EF
# 0     0X100CF05D141FF143.avi      0  59.7213
# 1     0X100CF05D141FF143.avi     55  62.2594
# 2     0X100CF05D141FF143.avi    114  60.3004
# 3     0X100CF05D141FF143.avi    176  59.4434
# 4     0X1012703CDC1436FE.avi      0  38.3652
# ...                      ...    ...      ...
# 4103   0XF829F634971A0F7.avi     33  60.0346
# 4104   0XF829F634971A0F7.avi     78  59.6482
# 4105   0XFE6E32991136338.avi      0  32.6225
# 4106   0XFE6E32991136338.avi     13  34.2999
# 4107   0XFE6E32991136338.avi     41  33.7443
#
# [4108 rows x 3 columns]

# %%
beatByBeat=beatByBeat.groupby('FileName')['EF'].agg(['mean', std])
beatByBeat
# Out:
#                              mean       std
# FileName
# 0X100CF05D141FF143.avi  60.431125  1.099901
# 0X1012703CDC1436FE.avi  41.611067  2.320845
# 0X102CFB07F752AAE6.avi  48.551167  3.084236
# 0X105B9EF57DE45DCB.avi  54.114925  1.254199
# 0X10A28877E97DF540.avi  61.302233  0.744732
# ...                           ...       ...
# 0XECF82DC9301EE77.avi   66.004267  0.592930
# 0XF557EF658FD13D0.avi   56.655600  2.254399
# 0XF6661AF354401A5.avi   61.246925  1.634449
# 0XF829F634971A0F7.avi   59.516633  0.485624
# 0XFE6E32991136338.avi   33.555567  0.697678
#
# [1273 rows x 2 columns]

# %%
ActualNumbers=pd.read_csv('/content/FileList.csv')

# %%
ActualNumbers=ActualNumbers[['FileName','EF']]

# %%
ActualNumbers
# Out:
#                      FileName         EF
# 0      0X100009310A3BD7FC.avi  78.498406
# 1      0X1002E8FBACD08477.avi  59.101988
# 2      0X1005D03EED19C65B.avi  62.363798
# 3      0X10075961BC11C88E.avi  54.545097
# 4      0X10094BA0A028EAC3.avi  24.887742
# ...                       ...        ...
# 10025  0X234005774F4CB5CD.avi  51.724743
# 10026  0X2DC68261CBCC04AE.avi  62.187781
# 10027  0X35291BE9AB90FB89.avi  62.070762
# 10028  0X6C435C1B417FDE8A.avi  59.635257
# 10029  0X5515B0BD077BE68A.avi  46.019994
#
# [10030 rows x 2 columns]

# %%
dataNoAugmentation
# Out:
#                       FileName  Frame       EF
# 0       0X100CF05D141FF143.avi      0  59.7213
# 186     0X1012703CDC1436FE.avi      0  38.3652
# 325     0X102CFB07F752AAE6.avi      0  52.7867
# 480     0X105B9EF57DE45DCB.avi      0  55.8331
# 620     0X10A28877E97DF540.avi      0  60.6997
# ...                        ...    ...      ...
# 146702   0XECF82DC9301EE77.avi      0  66.8003
# 146816   0XF557EF658FD13D0.avi      0  55.5773
# 146933   0XF6661AF354401A5.avi      0  61.6972
# 147092   0XF829F634971A0F7.avi      0  58.8671
# 147213   0XFE6E32991136338.avi      0  32.6225
#
# [1276 rows x 3 columns]

# %%
dataNoAugmentation=pd.merge(dataNoAugmentation, ActualNumbers,how='left',on='FileName')

# %%
dataNoAugmentation
# Out:
#                     FileName  Frame     EF_x       EF_y
# 0     0X100CF05D141FF143.avi      0  59.3047  55.951790
# 1     0X1012703CDC1436FE.avi      0  40.5933  41.014425
# 2     0X102CFB07F752AAE6.avi      0  55.0932  50.794718
# 3     0X105B9EF57DE45DCB.avi      0  57.2769  50.634981
# 4     0X10A28877E97DF540.avi      0  60.3366  63.098086
# ...                      ...    ...      ...        ...
# 1271   0XECF82DC9301EE77.avi      0  66.2269  63.867921
# 1272   0XF557EF658FD13D0.avi      0  60.6499  52.836650
# 1273   0XF6661AF354401A5.avi      0  59.3366  64.829583
# 1274   0XF829F634971A0F7.avi      0  59.7407  65.125501
# 1275   0XFE6E32991136338.avi      0  34.5197  32.783248
#
# [1276 rows x 4 columns]

# %%
dataNoAugmentation['EF_x'].mean()
# Out:
# 55.529334952978054

# %%
dataNoAugmentation['AbsErr']=abs(dataNoAugmentation['EF_x']-dataNoAugmentation['EF_y'])

# %%
dataNoAugmentation
# Out:
#                     FileName  Frame     EF_x       EF_y    AbsErr
# 0     0X100CF05D141FF143.avi      0  59.3047  55.951790  3.352910
# 1     0X1012703CDC1436FE.avi      0  40.5933  41.014425  0.421125
# 2     0X102CFB07F752AAE6.avi      0  55.0932  50.794718  4.298482
# 3     0X105B9EF57DE45DCB.avi      0  57.2769  50.634981  6.641919
# 4     0X10A28877E97DF540.avi      0  60.3366  63.098086  2.761486
# ...                      ...    ...      ...        ...       ...
# 1271   0XECF82DC9301EE77.avi      0  66.2269  63.867921  2.358979
# 1272   0XF557EF658FD13D0.avi      0  60.6499  52.836650  7.813250
# 1273   0XF6661AF354401A5.avi      0  59.3366  64.829583  5.492983
# 1274   0XF829F634971A0F7.avi      0  59.7407  65.125501  5.384801
# 1275   0XFE6E32991136338.avi      0  34.5197  32.783248  1.736452
#
# [1276 rows x 5 columns]

# %%
np.mean(dataNoAugmentation['AbsErr'])
# Out:
# 4.179791121520377

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(dataNoAugmentation['EF_x'], dataNoAugmentation['EF_y'], squared=False)
# Out:
# 5.551637969760843

# %%
from sklearn.metrics import r2_score
r2_score(dataNoAugmentation['EF_x'], dataNoAugmentation['EF_y'])
# Out:
# 0.7595108491700011

# %%
beatByBeat=pd.merge(beatByBeat,ActualNumbers,how='left',on='FileName')
beatByBeat['mean'].mean()
# Out:
# 55.69193909160361

# %%
beatByBeat['Abs']=abs(beatByBeat['mean']-beatByBeat['EF'])
beatByBeat
# Out:
#                     FileName       mean       std         EF       Abs
# 0     0X100CF05D141FF143.avi  60.334750  0.770572  55.951790  4.382960
# 1     0X1012703CDC1436FE.avi  38.373467  1.739667  41.014425  2.640958
# 2     0X102CFB07F752AAE6.avi  49.562167  3.964445  50.794718  1.232551
# 3     0X105B9EF57DE45DCB.avi  56.044250  0.723629  50.634981  5.409269
# 4     0X10A28877E97DF540.avi  61.656767  1.506618  63.098086  1.441319
# ...                      ...        ...       ...        ...       ...
# 1268   0XECF82DC9301EE77.avi  66.283667  0.143198  63.867921  2.415745
# 1269   0XF557EF658FD13D0.avi  60.730467  0.916779  52.836650  7.893816
# 1270   0XF6661AF354401A5.avi  60.035825  1.276732  64.829583  4.793758
# 1271   0XF829F634971A0F7.avi  59.966533  0.204342  65.125501  5.158968
# 1272   0XFE6E32991136338.avi  35.578967  0.993826  32.783248  2.795718
#
# [1273 rows x 5 columns]

# %%
np.mean(beatByBeat['Abs'])
# Out:
# 3.971836470415815

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(beatByBeat['mean'], beatByBeat['EF'], squared=False)
# Out:
# 5.293464663159433

# %%
from sklearn.metrics import r2_score
r2_score(beatByBeat['mean'], beatByBeat['EF'])
# Out:
# 0.7709291162545451

# %%
import pandas as pd

# %%
df = pd.read_csv("FileList.csv")

# %%
df

df1=df[df['Split']=='TEST']
df1
df1['EF'].mean()
# Out:
# 55.499501119647604

# %%
df['EF'].mean()
# Out:
# 55.74824810192034

# %%
dataNoAugmentation['EF_y'].mean()
# Out:
# 55.493864462100305

# %%
dataNoAugmentation['EF_x'].mean()
# Out:
# 55.529334952978054

# %%
import matplotlib.pyplot as plt

plt.plot(df["EF"])

# %%
 median_column = df["EF"]
median_column.plot(kind="hist")

# %%
plt.style.use('ggplot')
plt.xlabel('EF')
plt.ylabel('Frequency')
plt.hist(df["EF"], bins = 100)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
fig, ax = plt.subplots()
data = df['EF']

N, bins, patches = ax.hist(data, edgecolor='white', linewidth=1,bins=100)

for i in range(0,54):
    patches[i].set_facecolor('red')
for i in range(55,75):    
    patches[i].set_facecolor('green')
for i in range(76, len(patches)):
    patches[i].set_facecolor('red')

plt.xlabel('EF')
plt.ylabel('Frequency')
plt.show()

# %%
import numpy as np 
from scipy.stats import t

# %%
cs = pd.read_csv("test_dice (10).csv")

# %%
cs
# Out:
#                     Filename   Overall     Large     Small
# 0     0X100CF05D141FF143.avi  0.955875  0.946154  0.961686
# 1     0X1012703CDC1436FE.avi  0.949918  0.934557  0.961319
# 2     0X102CFB07F752AAE6.avi  0.951764  0.944792  0.956431
# 3     0X105B9EF57DE45DCB.avi  0.926717  0.949465  0.912106
# 4     0X10A28877E97DF540.avi  0.960015  0.952479  0.964286
# ...                      ...       ...       ...       ...
# 1271   0XECF82DC9301EE77.avi  0.924228  0.876697  0.949593
# 1272   0XF557EF658FD13D0.avi  0.925953  0.927077  0.925256
# 1273   0XF6661AF354401A5.avi  0.927193  0.914320  0.934625
# 1274   0XF829F634971A0F7.avi  0.936318  0.908054  0.951471
# 1275   0XFE6E32991136338.avi  0.940385  0.922370  0.954473
#
# [1276 rows x 4 columns]

# %%
x= cs[' Overall']
y=cs[' Large']
zz=cs[' Small']

# %%
m = zz.mean() 
s =zz.std() 
dof = len(zz)-1 
confidence = 0.95

# %%
t_crit = np.abs(t.ppf((1-confidence)/2,dof))

# %%
(m-s*t_crit/np.sqrt(len(zz)), m+s*t_crit/np.sqrt(len(zz)))
# Out:
# (0.9284470541673583, 0.9320559520576749)

# %%
import matplotlib.pyplot as plt
import statistics
from math import sqrt


def plot_confidence_interval(x, values, z=1.96,color='#2187bb',horizontal_line_width=0.25):
    mean = statistics.mean(values)
    stdev = statistics.stdev(values)
    confidence_interval = z * stdev / sqrt(len(values))

    left = x - horizontal_line_width / 2
    top = mean - confidence_interval
    right = x + horizontal_line_width / 2
    bottom = mean + confidence_interval
    plt.plot([x, x], [top, bottom], color=color)
    plt.plot([left, right], [top, top], color=color)
    plt.plot([left, right], [bottom, bottom], color=color)
    plt.plot(x, mean, 'o', color='#f44336')

    return mean, confidence_interval

plt.style.use('ggplot')
plt.xticks([1, 2, 3, 4], ['Overall DSC', 'Diastole DSC', 'Systole DSC'])
plt.title('Confidence Interval')
plot_confidence_interval(1, x)
plot_confidence_interval(2, y)
plot_confidence_interval(3, zz)
plt.show()
